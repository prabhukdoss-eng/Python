# %%
num1=20
num2=10
add = num1 + num2
print(add)
# Out:
# 30

# %%
multi=num1*num2
print(multi)
# Out:
# 200

# %%
div=num1/num2
print(div)
# Out:
# 2.0

# %%
num1=20
print(num1)
print(div)
# Out:
# 20
# 2.0

# %%
FirstName ='Prabu'
LastName = 'doss'
print(FirstName)
# Out:
# Prabu

# %%
FirstName ='Prabu'
LastName = 'doss'
print(FirstName+LastName)
# Out:
# Prabudoss

# %%
print("Program to add Two numbers")
num1=10
print("The first no is :",num1)
num2=30
print("The second no is :",num2)
print("The additon of two nos is:",num1+num2)
# Out:
# Program to add Two numbers
# The first no is : 10
# The second no is : 30
# The additon of two nos is: 40

# %%
# addtion of two nos by giving the value
num1= input("Enter the num1:")
num2= input("Emter the num2:")
add=num1+num2
print(add)
# Out:
# Enter the num1: 12
# Emter the num2: 14
# 1214

# %%
# addtion of two no by giving the value and conveting to integer
num1= int(input("Enter the num1:"))
num2= int(input("Emter the num2:"))
add=num1+num2
print(add)
# Out:
# Enter the num1: 12
# Emter the num2: 56
# 68

# %%
if 0:
    print('a')
else:
    print('b')
# Out:
# b

# %%
for i in range(3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
lists=[1, 2, 'q', 4]

# %%
print(len(lists))
# Out:
# 4
