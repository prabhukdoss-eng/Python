# %%
# using function to identify age category

# %%
lists =[10,20,30,40,50,15]
def ageCategory():
    for age in lists:
        if(age<18):
            print('Child')
        elif(age>18 and age<30):
            print('adult')
        else:
            print('senior')

# %%
ageCategory()
# Out:
# Child
# adult
# senior
# senior
# senior
# Child

# %%
def ageCategory():
        if(age<18):
            print('Child')
            cate='Child'
        elif(age>18 and age<30):
            print('adult')
            cate='Adult'
        else:
            print('senior')
            cate='Senior'
        return cate
# Out:
# Enter the age: 15

# %%
ageCategory()
# Out:
# Child
# 'Child'

# %%
Agecate=ageCategory()
# Out:
# Child

# %%
def ageCategory():
        if(age<18):
            cate='Child'
        elif(age>18 and age<30):
            cate='Adult'
        else:
            cate='Senior'
        return cate

# %%
age=int(input('Enter the age:'))
Agecate =ageCategory()
Agecate
# Out:
# Enter the age: 15
# 'Child'

# %%
# Parametirized functions

# %%
def add(num1,num2):
    numadd=num1+num2
    return numadd

# %%
add(5,3)
# Out:
# 8
