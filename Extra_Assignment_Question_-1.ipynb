# %%
print('HOPE AI')
# Out:
# HOPE AI

# %%
# Buy input
input("Enter your insitute name:")
# Out:
# Enter your insitute name: HOPE AI
# 'HOPE AI'

# %%
## With out assigning variable ,# Buy input

input("Enter your name:")
input("Enter your Age:")
input("Enter your School name:")
input("Enter your Degree:")
# Out:
# Enter your name: Prabu
# Enter your Age: 30
# Enter your School name: RCT
# Enter your Degree: B.E
# 'B.E'

# %%
## With assigning variable # Buy input
name = input("Enter your name:")
age = input("Enter your age:")
schoolname = input("Enter your school name:")
degree = input("Enter your drgree:")
# Out:
# Enter your name: Prabu
# Enter your age: 30
# Enter your school name: rct
# Enter your drgree: B.E

# %%
#addition
a=43
b=34
print('add:',a+b)
# Out:
# add: 77

# %%
#Subtraction
a=43
b=34
print('sub:',a-b)
# Out:
# sub: 9

# %%
# addtion by assigning varianle
a=int(input("Enter the value of A :"))
b=int(input("Enter the value of B :"))
print('THe sum of a and b:',a+b)
# Out:
# Enter the value of A : 12
# Enter the value of B : 12
# THe sum of a and b: 24

# %%
#multipication
a=int(input("Enter the value of A :"))
b=int(input("Enter the value of B :"))
print('THe sum of a and b:',a*b)
# Out:
# Enter the value of A : 63
# Enter the value of B : 97
# THe sum of a and b: 6111

# %%
a=int(input("Enter the value of A :"))
b=int(input("Enter the value of B :"))
print('Float Div:',a/b)
# Out:
# Enter the value of A : 76
# Enter the value of B : 31
# Float Div: 2.4516129032258065

# %%
a=int(input("Enter the value of A :"))
b=int(input("Enter the value of B :"))
print("floor div:",a//b)
# Out:
# Enter the value of A : 76
# Enter the value of B : 31
# floor div: 2

# %%
a=int(input("Enter the value of A :"))
b=int(input("Enter the value of B :"))
print("Modulo:",(a%b))
# Out:
# Enter the value of A : 76
# Enter the value of B : 31
# floor div: 14

# %%
a=int(input("Enter the value of A :"))
b=int(input("Enter the value of B :"))
print("floor div:",a**b)
# Out:
# Enter the value of A : 4
# Enter the value of B : 4
# floor div: 256
