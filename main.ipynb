# %%
from Multifunctions import multiplefunctions
#from filename import classname

# %%
multiplefunctions.Findpercent()
# Out:
# Enter the Subject1 :  90
# Enter the Subject2 :  56
# Enter the Subject3 :  67
# Enter the Subject4 :  89
# Enter the Subject5 :  34
# ('Total:', 336, 'Percent :', 67.2)

# %%
multiplefunctions.Elegible()
# Out:
# Your gender :  male
# Your age :  35
# you are not elible for marriage
# 'you are not elible for marriage'

# %%
print(3 * "abc")
# Out:
# abcabcabc
